# %% [markdown]
# # Evaluation Project 3 Avacado Project
#
# Problem Statement:
# Avocado is a fruit consumed by people heavily in the United States.
#
# Content :
#
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags. The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.
#
# Some relevant columns in the dataset:
#
# Date - The date of the observation
# AveragePrice - the average price of a single avocado
# type - conventional or organic
# year - the year
# Region - the city or region of the observation
# Total Volume - Total number of avocados sold
# 4046 - Total number of avocados with PLU 4046 sold
# 4225 - Total number of avocados with PLU 4225 sold
# 4770 - Total number of avocados with PLU 4770 sold
# Inspiration /Label
#
# The dataset can be seen in two angles to find the region and find the average price .
#
# Task: One of Classification and other of Regression
#
# Do both tasks in the same .ipynb file and submit at single file.
#
# To download the dataset, use the link given below.
#
# Downlaod Files: https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/avocado.csv.zip
#
# Importing require library for performing EDA, Data Wrangling and data cleaning

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\utkar\Downloads\avocado.csv (1)\avocado.csv")
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.tail(5)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.value_counts()
# Out:
# Date        AveragePrice  Total Volume  4046       4225        4770      Total Bags  Small Bags  Large Bags  XLarge Bags  type          year  region
# 2015-01-04  0.65          1048062.16    770635.37  178418.32   6509.41   92499.06    92499.06    0.00        0.00         conventional  2015  PhoenixTucson          1
# 2017-02-26  1.29          260743.16     52855.29   139066.59   100.84    68720.44    66310.52    2332.14     77.78        conventional  2017  HarrisburgScranton     1
#             1.41          3584.79       844.97     9.94        0.00      2729.88     2247.72     482.16      0.00         organic       2017  Pittsburgh             1
#             1.40          88371.09      3190.28    73959.76    71.20     11149.85    10910.40    239.45      0.00         conventional  2017  Albany                 1
#             1.39          76034.02      6058.09    24558.45    1293.32   44124.16    20679.02    23445.14    0.00         organic       2017  Plains                 1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
df['Date'].dtype
# Out:
# dtype('O')

# %%
df['Date']=pd.to_datetime(df.Date)

# %% [markdown]
# # finding Missing values

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # Statistical Analysis

# %%
df.describe().T
# Out:
#                 count           mean           std      min       25%  \
# AveragePrice  18249.0       1.405978  4.026766e-01     0.44      1.10
# Total Volume  18249.0  850644.013009  3.453545e+06    84.56  10838.58
# 4046          18249.0  293008.424531  1.264989e+06     0.00    854.07
# 4225          18249.0  295154.568356  1.204120e+06     0.00   3008.78
# 4770          18249.0   22839.735993  1.074641e+05     0.00      0.00
# Total Bags    18249.0  239639.202060  9.862424e+05     0.00   5088.64
# Small Bags    18249.0  182194.686696  7.461785e+05     0.00   2849.42
# Large Bags    18249.0   54338.088145  2.439660e+05     0.00    127.47
# XLarge Bags   18249.0    3106.426507  1.769289e+04     0.00      0.00
# year          18249.0    2016.147899  9.399385e-01  2015.00   2015.00
#
#                     50%        75%          max
# AveragePrice       1.37       1.66         3.25
# Total Volume  107376.76  432962.29  62505646.52
# 4046            8645.30  111020.20  22743616.17
# ...

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df.describe().T,fmt='0.1f',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.177088   -0.174730   -0.172940    -0.117592  0.093197
# ...

# %%
sns.heatmap(df.corr(),cmap='cividis',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Exploratory data Analysis

# %%
df.AveragePrice.min()
# Out:
# 0.44

# %%
df.AveragePrice.max()
# Out:
# 3.25

# %%
df.AveragePrice.mean()
# Out:
# 1.405978409775878

# %%
plt.figure(figsize=(12,7))
plt.title('Distribution Price')
sns.distplot(df["AveragePrice"], color='r')
# Out:
# <Axes: title={'center': 'Distribution Price'}, xlabel='AveragePrice', ylabel='Density'>

# %%
df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
labels = 'conventinal','organic',
fig, ax = plt.subplots()
ax.pie(df['type'].value_counts(),labels = labels,radius =1,autopct = '%2.2f%%',explode=[0.1,0.2], shadow=True,)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.set(style="darkgrid")  

sns.countplot(data=df, x="type", palette="Set1")

plt.xlabel("type")
plt.ylabel("Count")
plt.title("Countplot of type")

plt.show()

# %%
df.groupby('type')['AveragePrice'].mean()
# Out:
# type
# conventional    1.158040
# organic         1.653999
# Name: AveragePrice, dtype: float64

# %%
variables_to_plot = ['AveragePrice','Total Volume']
plt.figure(figsize=(6, 6))
sns.set(style="whitegrid")

for variable in variables_to_plot:
    sns.boxplot(y=variable, data=df, color='skyblue', width=0.4)
    plt.title(f'Box Plot of {variable}')
    plt.ylabel(variable)
    plt.show()

# %%
average_prices_by_region = df.groupby('region')['AveragePrice'].mean().reset_index()

average_prices_by_region = average_prices_by_region.sort_values(by='AveragePrice', ascending=False)

plt.figure(figsize=(12, 6))
plt.bar(average_prices_by_region['region'], average_prices_by_region['AveragePrice'])
plt.xlabel('Region')
plt.ylabel('Average Price')
plt.title('Average Avocado Price by Region')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
average_consumption_by_region = df.groupby('region')['Total Volume'].mean().reset_index()

average_consumption_by_region = average_consumption_by_region.sort_values(by='Total Volume', ascending=False)

plt.figure(figsize=(12, 6))
plt.bar(average_consumption_by_region['region'], average_consumption_by_region['Total Volume'])
plt.xlabel('Region')
plt.ylabel('Average Consumption (Total Volume)')
plt.title('Average Avocado Consumption by Region')
plt.xticks(rotation=90) 

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(x='region', y='AveragePrice', data=df, hue='year', dodge=True)
plt.xlabel('Region')
plt.ylabel('Average Price')
plt.title('Swarm Plot of Region vs. Average Price (Colored by Year)')
plt.xticks(rotation=90)

plt.legend(title='Year')

plt.tight_layout()
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])

average_price_by_date = df.groupby('Date')['AveragePrice'].mean()

plt.figure(figsize=(12, 6))
plt.plot(average_price_by_date.index, average_price_by_date.values, marker='o', linestyle='-')
plt.xlabel('Date')
plt.ylabel('Average Price')
plt.title('Average Avocado Price Over Time')
plt.grid(True)

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='AveragePrice', data=df)
plt.xlabel('Average Price')
plt.title('Violin Plot of Average Price in Avocado Dataset')
plt.show()

# %%
features_to_plot = ['AveragePrice', 'Total Volume', 'Total Bags']

fig, axes = plt.subplots(nrows=1, ncols=len(features_to_plot), figsize=(15, 5))

for i, feature in enumerate(features_to_plot):
    sns.violinplot(x=feature, data=df, ax=axes[i])
    axes[i].set_xlabel(feature)
    axes[i].set_title(f'Violin Plot of {feature}')
    
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

categories = ['Starting', 'AveragePrice', 'TotalVolume', 'year', 'Ending']
values = [100, 20, -10, 30, 0]  # Replace 'None' with 0 or the actual ending value

cumulative_values = [values[0]]
for i in range(1, len(values)):
    cumulative_values.append(cumulative_values[i-1] + values[i])

plt.bar(categories, cumulative_values, color=['b', 'g', 'r', 'g', 'b'], alpha=0.7)
plt.xlabel('Categories')
plt.ylabel('Value')
plt.title('Waterfall Chart')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
df.plot(kind='box',subplots=True,layout=(6,6),figsize=(10,14))
# Out:
# AveragePrice        Axes(0.125,0.77;0.110714x0.11)
# Total Volume     Axes(0.257857,0.77;0.110714x0.11)
# 4046             Axes(0.390714,0.77;0.110714x0.11)
# 4225             Axes(0.523571,0.77;0.110714x0.11)
# 4770             Axes(0.656429,0.77;0.110714x0.11)
# Total Bags       Axes(0.789286,0.77;0.110714x0.11)
# Small Bags         Axes(0.125,0.638;0.110714x0.11)
# Large Bags      Axes(0.257857,0.638;0.110714x0.11)
# XLarge Bags     Axes(0.390714,0.638;0.110714x0.11)
# type            Axes(0.523571,0.638;0.110714x0.11)
# year            Axes(0.656429,0.638;0.110714x0.11)
# region          Axes(0.789286,0.638;0.110714x0.11)
# dtype: object

# %%
sns.pairplot(df)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['region']=le.fit_transform(df['region'])
df['type']=le.fit_transform(df['type'])
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region
# 0     8696.87     8603.62       93.25          0.0     0  2015       0
# 1     9505.56     9408.07       97.49          0.0     0  2015       0
# 2     8145.35     8042.21      103.14          0.0     0  2015       0
# 3     5811.16     5677.40      133.76          0.0     0  2015       0
# 4     6183.95     5986.26      197.69          0.0     0  2015       0

# %% [markdown]
# # Outlier Detection and Removal

# %%
import pandas as pd
import numpy as np
from scipy.stats import zscore

numerical_columns = df.select_dtypes(include=[np.number])

z_scores = zscore(numerical_columns)

z_score_df = pd.DataFrame(z_scores, columns=numerical_columns.columns)

threshold = 3

df1 = df[(z_score_df < threshold).all(axis=1)]

# %%
df1.shape
# Out:
# (17651, 13)

# %%
df1.drop(columns=['4046','4225','4770','region','Total Bags'],axis=1, inplace=True) ##dropping unnecessary columns which are of no use

# %% [markdown]
# # Checking Multicollinearity between features using variance_inflation_factor

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor

numeric_columns = df1.select_dtypes(include=[np.number])

vif = pd.DataFrame()
vif["Features"] = numeric_columns.columns
vif["VIF"] = [variance_inflation_factor(numeric_columns.values, i) for i in range(numeric_columns.shape[1])]

print(vif)
# Out:
#        Features        VIF
# 0  AveragePrice  23.425802
# 1  Total Volume   7.753656
# 2    Small Bags   7.707137
# 3    Large Bags   1.968745
# 4   XLarge Bags   1.693446
# 5          type   3.586528
# 6          year  18.828925

# %%
df1.drop(columns=['year'],axis=1, inplace=True)

# %%
df1.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    3.767138
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# dtype: float64

# %%
import numpy as np
import pandas as pd
from scipy.stats import skew

numeric_columns = df1.select_dtypes(include=[np.number])

skewness = numeric_columns.apply(lambda x: skew(x))

skew_threshold = 0.55

for col in numeric_columns.columns:
    if skewness[col] > skew_threshold:
        numeric_columns[col] = np.log1p(numeric_columns[col])

# %%
X = df1.drop('AveragePrice', axis=1)
Y = df1['AveragePrice']

# %% [markdown]
# # Standard Scaling

# %%
from sklearn.preprocessing import StansardScaler
if 'Date' in X.columns:
    X = X.drop(columns=['Date'])

scaler = StandardScaler()

X_scale = scaler.fit_transform(X)

# %% [markdown]
# # Machine Learning Model Building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=42, test_size=.33)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=557, test_size=.33)
lin_reg=LinearRegression()
lin_reg.fit(X_train,Y_train)
lin_reg.score(X_train,Y_train)
y_pred=lin_reg.predict(X_test)
print('\033[1m'+'Predicted Wins:'+'\033[0m\n',y_pred)
print('\n')
print('\033[1m'+'Actual Wins:'+'\033[0m\n',Y_test)
# Out:
# Predicted Wins:
#  [1.16424821 1.20190396 1.63331147 ... 1.63351218 1.63408343 1.63382606]
#
#
# Actual Wins:
#  8841     1.35
# 859      1.19
# 17369    2.09
# 11190    1.05
# 14051    2.03
#          ...
# 5452     1.05
# 3489     1.35
# 14534    1.22
# 11925    1.71
# 11077    1.83
# Name: AveragePrice, Length: 5825, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
print('\033[1m'+' Error :'+'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
from sklearn.metrics import r2_score
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(Y_test,y_pred,multioutput='variance_weighted'))
# Out:
#  Error :
# Mean absolute error : 0.2343501298342748
# Mean squared error : 0.08944491124326286
# Root Mean Squared Error: 0.2990734211581879
#
#
#  R2 Score :
# 0.4134550895224429

# %% [markdown]
# # Cross validation

# %%
#Cross Validation
from sklearn.model_selection import cross_val_score
score = cross_val_score(lin_reg, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score :',lin_reg,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())

# %%
rf = RandomForestRegressor(n_estimators = 70 ,max_depth=25)
dtc = DecisionTreeRegressor()
adb=AdaBoostRegressor(learning_rate=0.1)
gradb=GradientBoostingRegressor(max_depth=25,learning_rate=0.1)
rd=Ridge(alpha=0.01)
model = [rf,rd,dtc,adb,gradb]

for m in model:
    m.fit(X_train,Y_train)
    m.score(X_train,Y_train)
    y_pred = m.predict(X_test)
    print('\n')                                        
    print('\033[1m'+' Error of ', m, ':' +'\033[0m')
    print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
    print('Mean squared error :', mean_squared_error(Y_test,y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
    print('\n')

    print('\033[1m'+' R2 Score :'+'\033[0m')
    print(r2_score(Y_test,y_pred))
# Out:
#  Error of  RandomForestRegressor(max_depth=25, n_estimators=70) :
# Mean absolute error : 0.17946640337006578
# Mean squared error : 0.05824703306440347
# Root Mean Squared Error: 0.24134422111250867
#
#
#  R2 Score :
# 0.6180386304881356
#
#
#  Error of  Ridge(alpha=0.01) :
# Mean absolute error : 0.2343501435368269
# Mean squared error : 0.08944491733445613
# Root Mean Squared Error: 0.2990734313416291
#
#
#  R2 Score :
# 0.41345504957876844
#
#
#  Error of  DecisionTreeRegressor() :
# Mean absolute error : 0.2338283261802575
# Mean squared error : 0.10886181974248926
# Root Mean Squared Error: 0.32994214605365174
#
#
#  R2 Score :
# 0.28612656183845453
#
#
#  Error of  AdaBoostRegressor(learning_rate=0.1) :
# Mean absolute error : 0.22305924649637474
# Mean squared error : 0.07848738770418026
# Root Mean Squared Error: 0.2801560060112584
#
#
#  R2 Score :
# 0.48531026355025564
#
#
#  Error of  GradientBoostingRegressor(max_depth=25) :
# Mean absolute error : 0.22351180823757633
# ...

# %%
data = pd.DataFrame({'Y Test':Y_test , 'Pred':y_pred},columns=['Y Test','Pred'])
sns.swarmplot(x='Y Test',y='Pred',data=data,palette='rainbow')
data.head()
# Out:
#        Y Test      Pred
# 8841     1.35  1.386278
# 859      1.19  1.020710
# 17369    2.09  1.409334
# 11190    1.05  1.448355
# 14051    2.03  1.942637

# %% [markdown]
# # Saving the final model

# %%
import joblib
joblib.dump(model,'Avacado_Final.pkl')
# Out:
# ['Avacado_Final.pkl']
